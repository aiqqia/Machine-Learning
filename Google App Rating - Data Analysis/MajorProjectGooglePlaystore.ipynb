# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

sns.set_style('darkgrid')
plt.rcParams['font.size'] = 18
plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['figure.facecolor'] = '#000033'

# %%
df = pd.read_csv('googleplaystore.csv')
df.head()
# Out:
#                                                  App  ...   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                Coloring book moana  ...  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                              Sketch - Draw & Paint  ...    4.2 and up
# 4              Pixel Draw - Number Art Coloring Book  ...    4.4 and up
#
# [5 rows x 13 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %%
df['Type'].fillna("Free", inplace = True) #Since most apps are free

# %%
df['Content Rating'].value_counts()
# Out:
# Everyone           8714
# Teen               1208
# Mature 17+          499
# Everyone 10+        414
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
df['Content Rating'].fillna("Everyone", inplace = True) #Most likely

# %%
df['Rating'].fillna(value=df['Rating'].median(), inplace = True) #Since many missing values, safer bet to replace with median

# %%
df.drop(['Current Ver','Last Updated', 'Android Ver'], axis=1, inplace=True) #Redundant

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# dtype: int64

# %%
df.describe()
# Out:
#              Rating
# count  10841.000000
# mean       4.207841
# std        0.500893
# min        1.000000
# 25%        4.100000
# 50%        4.300000
# 75%        4.500000
# max       19.000000

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# dtype: object

# %%
df['Size'] = df.Reviews.astype(object)

# %%
#Removing unwanted symbols
df['Size'] = df.Size.apply(lambda x: x.strip('+'))
df['Installs'] = df.Installs.apply(lambda x: x.strip('+'))
df['Size'] = df.Size.apply(lambda x: x.replace(',', ''))
df['Installs'] = df.Installs.apply(lambda x: x.replace(',', ''))
df['Size'] = df.Size.apply(lambda x: x.replace('M', 'e+6'))
df['Size'] = df.Size.apply(lambda x: x.replace('k', 'e+3'))
df['Price'] = df.Price.apply(lambda x: x.strip('$'))
df['Size'] = df.Size.replace('Varies with device', np.NaN)

df['Size'] = pd.to_numeric(df['Size']) 
#df['Installs'] = pd.to_numeric(df['Installs'])
#df['Price'] = pd.to_numeric(df['Price'])

df.dropna(subset = ['Size'], inplace=True)

# %%
df['Installs'].value_counts()
# Out:
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           907
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Free             1
# Name: Installs, dtype: int64

# %%
df['Installs'].replace(to_replace = ['Free'], value =[0], inplace=True)

# %%
df['Price'].value_counts()
# Out:
# 0         10040
# 0.99        148
# 2.99        129
# 1.99         73
# 4.99         72
#           ...
# 379.99        1
# 1.26          1
# 3.61          1
# 4.84          1
# 5.00          1
# Name: Price, Length: 93, dtype: int64

# %%
df['Installs'] = pd.to_numeric(df['Installs'])

# %%
df['Price'].replace(to_replace = ['Everyone'], value =[0], inplace=True)
df['Price'] = pd.to_numeric(df['Price'])

# %%
x = df['Content Rating'].value_counts().index
y = df['Content Rating'].value_counts()

xsis = []
ysis = []
for i in range(len(x)):
    xsis.append(x[i])
    ysis.append(y[i])

# %%
plt.figure(figsize=(12,10))
plt.bar(xsis,ysis,width=0.8,color=['#15244C','#FFFF48','#292222','#EF2333','#CD202D','#ECC5F2'], alpha=0.8);
plt.title('Content Rating',size = 20);
plt.ylabel('Apps(Count)');
plt.xlabel('Content Rating');

# %%
plt.figure(figsize=(15,9))
plt.xlabel("Rating")
plt.ylabel("Frequency")
graph = sns.kdeplot(df.Rating, color="Blue", shade = True)
plt.title('Distribution of Rating',size = 20);

# %%
plt.figure(figsize=(18,13))
plt.xlabel("Count")
plt.ylabel("Category")

graph = sns.barplot(x = xsis, y = ysis, palette= "husl")
graph.set_title("Top categories on Google Playstore", fontsize = 25);

# %%
def findtop10incategory(str):
    str = str.upper()
    top10 = df[df['Category'] == str]
    top10apps = top10.sort_values(by='Installs', ascending=False).head(10)
    # Top_Apps_in_art_and_design
    plt.figure(figsize=(15,12))
    plt.title('Top 10 Installed Apps',size = 20);    
    graph = sns.barplot(x = top10apps.App, y = top10apps.Installs)
    graph.set_xticklabels(graph.get_xticklabels(), rotation= 45, horizontalalignment='right');

# %%
findtop10incategory('Sports')

# %%
top10PaidApps = df[df['Type'] == 'Paid'].sort_values(by='Price', ascending=False).head(11)
# top10PaidApps

# %%
top10PaidApps_df = top10PaidApps[['App', 'Installs']].drop(9934)

# %%
plt.figure(figsize=(15,12));
plt.pie(top10PaidApps_df.Installs, explode=None, labels=top10PaidApps_df.App, autopct='%1.1f%%', startangle=0);
plt.title('Top Expensive Apps Distribution',size = 20);
plt.legend(top10PaidApps_df.App, 
           loc="lower right",
           title="Apps",
           fontsize = "xx-small"
          );
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 128142 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 128142 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#So, here we have a detailed analysis of Google PlayStore Apps.
#General Trends have been shown using a variety of charts.


#While comparing the content rating of apps, we established that apps available for everyone exceed in number, 
#followed by apps available for teens, mature 17+, and everyone 10+. 
#There are negligible apps that are rated as adults only, 18+ or are left unrated. 

#Most apps have been rated around 4 stars while negligible apps have been rated 5 stars and 
#even lesser apps have been rated around 2.5 stars.

#We have also found top the top 10 installed apps which are Fifa Soccer, Dream League Soccer, and so on as shown in the graph.

#From the pie chart about top expensive apps distribution, almost 70% of the apps are moderately priced 
#while the rest 30% comprises the highly priced apps.
